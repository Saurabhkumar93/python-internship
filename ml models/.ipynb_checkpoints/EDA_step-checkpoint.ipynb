# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('crop_production.csv')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.shape
# Out:
# (246091, 7)

# %%
df.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 246086  West Bengal       PURULIA       2014  Summer            Rice
# 246087  West Bengal       PURULIA       2014  Summer         Sesamum
# 246088  West Bengal       PURULIA       2014  Whole Year   Sugarcane
# 246089  West Bengal       PURULIA       2014  Winter            Rice
# 246090  West Bengal       PURULIA       2014  Winter         Sesamum
#
#             Area  Production
# 246086     306.0       801.0
# 246087     627.0       463.0
# 246088     324.0     16250.0
# 246089  279151.0    597899.0
# 246090     175.0        88.0

# %%
nul = df.isna().sum()
nul
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
mod = df['Production'].median()
df['Production'].fillna(mod, inplace = True)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_16804\2104051993.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Production'].fillna(mod, inplace = True)

# %%
nul = df.isna().sum()
nul
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
dup = df.duplicated().sum()
dup
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.460910e+05
# mean     2005.643018  1.200282e+04  5.736855e+05
# std         4.952164  5.052340e+04  1.693613e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  9.100000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  6.769000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
colm = df.columns
colm
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
new_df = pd.get_dummies(df, columns = ['Season','Crop','State_Name'])
new_df
# Out:
#        District_Name  Crop_Year      Area  Production  Season_Autumn       \
# 0           NICOBARS       2000    1254.0      2000.0               False
# 1           NICOBARS       2000       2.0         1.0               False
# 2           NICOBARS       2000     102.0       321.0               False
# 3           NICOBARS       2000     176.0       641.0               False
# 4           NICOBARS       2000     720.0       165.0               False
# ...              ...        ...       ...         ...                 ...
# 246086       PURULIA       2014     306.0       801.0               False
# 246087       PURULIA       2014     627.0       463.0               False
# 246088       PURULIA       2014     324.0     16250.0               False
# 246089       PURULIA       2014  279151.0    597899.0               False
# 246090       PURULIA       2014     175.0        88.0               False
#
#         Season_Kharif       Season_Rabi         Season_Summer       \
# 0                     True               False               False
# 1                     True               False               False
# 2                     True               False               False
# 3                    False               False               False
# 4                    False               False               False
# ...                    ...                 ...                 ...
# 246086               False               False                True
# 246087               False               False                True
# 246088               False               False               False
# 246089               False               False               False
# 246090               False               False               False
#
#         Season_Whole Year   Season_Winter       ...  State_Name_Puducherry  \
# 0                    False               False  ...                  False
# 1                    False               False  ...                  False
# 2                    False               False  ...                  False
# 3                     True               False  ...                  False
# 4                     True               False  ...                  False
# ...                    ...                 ...  ...                    ...
# 246086               False               False  ...                  False
# 246087               False               False  ...                  False
# 246088                True               False  ...                  False
# 246089               False                True  ...                  False
# 246090               False                True  ...                  False
#
#         State_Name_Punjab  State_Name_Rajasthan  State_Name_Sikkim  \
# 0                   False                 False              False
# 1                   False                 False              False
# 2                   False                 False              False
# 3                   False                 False              False
# 4                   False                 False              False
# ...                   ...                   ...                ...
# 246086              False                 False              False
# 246087              False                 False              False
# 246088              False                 False              False
# 246089              False                 False              False
# 246090              False                 False              False
#
#         State_Name_Tamil Nadu  State_Name_Telangana   State_Name_Tripura  \
# 0                       False                  False               False
# 1                       False                  False               False
# 2                       False                  False               False
# 3                       False                  False               False
# 4                       False                  False               False
# ...                       ...                    ...                 ...
# 246086                  False                  False               False
# 246087                  False                  False               False
# 246088                  False                  False               False
# 246089                  False                  False               False
# 246090                  False                  False               False
#
#         State_Name_Uttar Pradesh  State_Name_Uttarakhand  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# ...                          ...                     ...
# 246086                     False                   False
# 246087                     False                   False
# 246088                     False                   False
# 246089                     False                   False
# 246090                     False                   False
#
#         State_Name_West Bengal
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 246086                    True
# 246087                    True
# 246088                    True
# 246089                    True
# 246090                    True
#
# [246091 rows x 167 columns]

# %%
cor = new_df.corr(numeric_only=True )
cor
# Out:
#                           Crop_Year      Area  Production  Season_Autumn       \
# Crop_Year                  1.000000 -0.026022    0.006827            0.034603
# Area                      -0.026022  1.000000    0.040655           -0.006492
# Production                 0.006827  0.040655    1.000000           -0.004743
# Season_Autumn              0.034603 -0.006492   -0.004743            1.000000
# Season_Kharif             -0.015967  0.041748   -0.025096           -0.114525
# ...                             ...       ...         ...                 ...
# State_Name_Telangana      -0.015169  0.007281   -0.004655           -0.021959
# State_Name_Tripura         0.037134 -0.013105   -0.002533           -0.010883
# State_Name_Uttar Pradesh   0.026992  0.007962   -0.011133           -0.056678
# State_Name_Uttarakhand     0.043095 -0.023023   -0.004599           -0.020411
# State_Name_West Bengal    -0.012047  0.041522   -0.005098            0.068232
#
#                           Season_Kharif       Season_Rabi         \
# Crop_Year                          -0.015967            0.043035
# Area                                0.041748            0.026013
# Production                         -0.025096           -0.019610
# Season_Autumn                      -0.114525           -0.087612
# Season_Kharif                       1.000000           -0.488899
# ...                                      ...                 ...
# State_Name_Telangana                0.009149            0.040254
# State_Name_Tripura                  0.020458            0.019297
# State_Name_Uttar Pradesh            0.037799            0.078382
# State_Name_Uttarakhand              0.023093            0.024079
# State_Name_West Bengal             -0.059478            0.030596
#
#                           Season_Summer       Season_Whole Year   \
# Crop_Year                           0.062486           -0.090079
# Area                               -0.034512           -0.081926
# Production                         -0.008409            0.057649
# Season_Autumn                      -0.036292           -0.078928
# Season_Kharif                      -0.202520           -0.440441
# ...                                      ...                 ...
# State_Name_Telangana               -0.038830           -0.014858
# State_Name_Tripura                 -0.019245           -0.025051
# State_Name_Uttar Pradesh            0.100068           -0.140656
# State_Name_Uttarakhand             -0.023991           -0.023415
# State_Name_West Bengal              0.048041           -0.024290
#
#                           Season_Winter       Crop_Apple  ...  \
# Crop_Year                           0.044999   -0.002559  ...
# Area                                0.076240   -0.000958  ...
# Production                         -0.004708   -0.000137  ...
# Season_Autumn                      -0.022759   -0.000578  ...
# Season_Kharif                      -0.127001   -0.003223  ...
# ...                                      ...         ...  ...
# State_Name_Telangana               -0.024351   -0.000618  ...
# State_Name_Tripura                 -0.012068   -0.000306  ...
# State_Name_Uttar Pradesh           -0.062852   -0.001595  ...
# State_Name_Uttarakhand             -0.022634   -0.000574  ...
# State_Name_West Bengal              0.029962   -0.000813  ...
#
#                           State_Name_Puducherry  State_Name_Punjab  \
# Crop_Year                              0.014683          -0.003195
# Area                                  -0.013458           0.063194
# Production                            -0.000475          -0.002624
# Season_Autumn                         -0.005646          -0.016373
# Season_Kharif                         -0.001896           0.029677
# ...                                         ...                ...
# State_Name_Telangana                  -0.009161          -0.017518
# State_Name_Tripura                    -0.004540          -0.008682
# State_Name_Uttar Pradesh              -0.023647          -0.045216
# State_Name_Uttarakhand                -0.008516          -0.016283
# State_Name_West Bengal                -0.012051          -0.023043
#
#                           State_Name_Rajasthan  State_Name_Sikkim  \
# Crop_Year                            -0.090838           0.005811
# Area                                  0.044598          -0.010536
# Production                           -0.007533          -0.001816
# Season_Autumn                        -0.033159          -0.007728
# Season_Kharif                         0.028017           0.022246
# ...                                        ...                ...
# State_Name_Telangana                 -0.035478          -0.008268
# State_Name_Tripura                   -0.017583          -0.004098
# State_Name_Uttar Pradesh             -0.091574          -0.021341
# State_Name_Uttarakhand               -0.032978          -0.007685
# State_Name_West Bengal               -0.046668          -0.010876
#
#                           State_Name_Tamil Nadu  State_Name_Telangana   \
# Crop_Year                             -0.037309              -0.015169
# Area                                  -0.023523               0.007281
# Production                             0.004529              -0.004655
# Season_Autumn                         -0.034577              -0.021959
# Season_Kharif                         -0.019397               0.009149
# ...                                         ...                    ...
# State_Name_Telangana                  -0.036996               1.000000
# State_Name_Tripura                    -0.018335              -0.011644
# State_Name_Uttar Pradesh              -0.095490              -0.060642
# State_Name_Uttarakhand                -0.034388              -0.021838
# State_Name_West Bengal                -0.048663              -0.030904
#
#                           State_Name_Tripura  State_Name_Uttar Pradesh  \
# Crop_Year                           0.037134                  0.026992
# Area                               -0.013105                  0.007962
# Production                         -0.002533                 -0.011133
# Season_Autumn                      -0.010883                 -0.056678
# Season_Kharif                       0.020458                  0.037799
# ...                                      ...                       ...
# State_Name_Telangana               -0.011644                 -0.060642
# State_Name_Tripura                  1.000000                 -0.030055
# State_Name_Uttar Pradesh           -0.030055                  1.000000
# State_Name_Uttarakhand             -0.010823                 -0.056367
# State_Name_West Bengal             -0.015316                 -0.079767
#
#                           State_Name_Uttarakhand  State_Name_West Bengal
# Crop_Year                               0.043095               -0.012047
# Area                                   -0.023023                0.041522
# Production                             -0.004599               -0.005098
# Season_Autumn                          -0.020411                0.068232
# Season_Kharif                           0.023093               -0.059478
# ...                                          ...                     ...
# State_Name_Telangana                   -0.021838               -0.030904
# State_Name_Tripura                     -0.010823               -0.015316
# State_Name_Uttar Pradesh               -0.056367               -0.079767
# State_Name_Uttarakhand                  1.000000               -0.028726
# State_Name_West Bengal                 -0.028726                1.000000
#
# [166 rows x 166 columns]
